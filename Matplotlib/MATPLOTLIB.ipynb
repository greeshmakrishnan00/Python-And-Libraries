# %% [markdown]
# <a href="https://colab.research.google.com/github/greeshmakrishnan00/Python-And-Libraries/blob/main/Matplotlib/MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# Matplotlib is a Python library for making graphs and charts. It helps you visualize data so you can understand patterns, trends, and relationships

# %% [markdown]
# ## Draw a line in a diagram from position (0,0) to position (6,250)

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ## marker the points

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# ## Draw a line in a diagram from position (1,3) to (2,8)then to (6,1) and (8,10)

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ## Default X points

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matpoltlib Markers

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# ## Format Strings fmt

# %% [markdown]
# You can use also use the shortcut string notation parameter to specify the marker.
# This parameter is also called fmt, and is written with this syntax:
# Marker|line|color.
#
# Eg: Mark each point with a circle.

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,'o:r')
plt.show()

# %% [markdown]
# ## Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='o',ms=10)
plt.show()

# %% [markdown]
# ## Marker Color

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='o',ms=10,mec='g') # markeredgecolor or the shorter mec
plt.show()

# %% [markdown]
# ## Matplotlib Line

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints, ls='dotted') #ls stands for linestyles
plt.show()

# %% [markdown]
# ## Line Color

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color='r')
plt.show()

# %% [markdown]
# ## Linewidth

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth='20.5')
plt.show()

# %% [markdown]
# ## Multiple Lines

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([0, 1, 2, 3])
y1=np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %% [markdown]
# With Pyplot, we can use the xlabel() and ylabel() functions to set a label for the x-axis and y-axis.

# %% [markdown]
# ## Labels

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ## Title

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ## Set Font Properties for Title and Labels

# %% [markdown]
# We can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)

font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}

plt.title("Sports Watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)
plt.show()

# %% [markdown]
# ## Position the Title

# %% [markdown]
# We can use the loc parameter in title() to position the title.
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# #Matplotlib Adding Grid Lines

# %% [markdown]
# With Pyplot, you can use the **grid()** function to add grid lines to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.grid()
plt.show()

# %% [markdown]
# Display only grid lines for the x-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.grid(axis='x')
plt.show()

# %% [markdown]
# set the line properties of grid.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.grid(color='green',ls='--',linewidth=0.5)
plt.show()

# %% [markdown]
# #Matplotlib Subplots

# %% [markdown]
# ## subplots()

# %% [markdown]
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x= np.array([0,1,2,3])
y= np.array([3,8,1,10])
plt.subplot(1,2,1)# 1 row, 2 column, 1 first plot
plt.plot(x,y)

#plot 2:
x= np.array([0,1,2,3])
y= np.array([10,20,30,40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x= np.array([0,1,2,3])
y= np.array([3,8,1,10])
plt.subplot(1,2,1)# 1 row, 2 column, 1 first plot
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x= np.array([0,1,2,3])
y= np.array([10,20,30,40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.show()

# %% [markdown]
# ## Suptitle

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x= np.array([0,1,2,3])
y= np.array([3,8,1,10])
plt.subplot(1,2,1)# 1 row, 2 column, 1 first plot
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x= np.array([0,1,2,3])
y= np.array([10,20,30,40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %% [markdown]
# With Pyplot, you can use the scatter() function to draw a scatter plot.
# The **scatter()** function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %% [markdown]
# draw two plots on the same figure

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Colors

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y, color='hotpink')

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,color='#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x,y, c= colors)

plt.show()

# %% [markdown]
# ##color map

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y, c= colors, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ## size

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y, c= colors, cmap='viridis',s=sizes)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Alpha

# %% [markdown]
# You **can adjust the transparency of the dots** with the alpha argument.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y,s=sizes,alpha=0.5)
plt.show()

# %% [markdown]
# ## Combine Color Size and Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))
size=10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=colors,s=size,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# # Matplotlib Bars

# %% [markdown]
# With pyplot() we can create bar graphs, we can use the bar() function to draw bar graphs .

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y)
plt.show()

# %% [markdown]
# ## Bar color

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color="red")
plt.show()

# %% [markdown]
# ## Bar Width

# %% [markdown]
# The bar() takes the keyword argument width to set the width of the bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color="red",width=0.1)
plt.show()

# %% [markdown]
# ## Bar Height

# %% [markdown]
# The barh() takes the keyword argument height to set the height of the bars:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y, height=0.1)
plt.show()

# %% [markdown]
# # Matplotlib Histograms

# %% [markdown]
# A histogram is a graph showing frequency distributions.
# It is a graph showing the number of observations within each given interval.
# In Matplotlib, we use the hist() function to create histograms.
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %% [markdown]
# A Normal Data Distribution by NumPy

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %% [markdown]
# # Matplotlib pie Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
plt.pie(y)
plt.show()

# %% [markdown]
# ## Labels

# %% [markdown]
# Add labels to the pie chart with the label parameter.

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
plt.pie(y,labels=mylabels)
plt.show()

# %% [markdown]
# ## Start Angle

# %% [markdown]
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
plt.pie(y,labels=mylabels,startangle=90)
plt.show()

# %% [markdown]
# ## Explode

# %% [markdown]
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
# Each value represents how far from the center each wedge is displayed:

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %% [markdown]
# Add a shadow to the pie chart by setting the shadows parameter to True:

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# ## Colors

# %%
# specify a new color for each wedge:
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
mycolors=["black", "hotpink", "b", "#4CAF50"]
plt.pie(y,labels=mylabels,colors=mycolors)
plt.show()

# %% [markdown]
# ##Legend

# %% [markdown]
# To add a list of explanation for each wedge, use the legend() function:

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.legend()
plt.show()

# %% [markdown]
# ## Legend with Header

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["A","B","C","D"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels)
plt.legend(title="Four Fruits: ")
plt.show()

# %% [markdown]
# #Waffle Chart

# %% [markdown]
# **A waffle chart is basically a square display, usually consisting of 100 smaller squares arranged in a 10-by-10 layout**.
# The squares are colored according to the proportions you are aiming to visualize,
# similarly to how you would color different slices of a pie chart. As this square layout somewhat resembles a delicious waffle

# %%
# !pip install pywaffle
import matplotlib.pyplot as plt
from pywaffle import Waffle

fig=plt.figure(
           FigureClass=Waffle,
           rows=5,
           columns=10,
           values=[48,46,6],
           figsize=(5,3)
)
plt.show()
# Out:
# ...
# <Waffle size 500x300 with 1 Axes>

# %% [markdown]
# ## Values in dict & Auto-sizing

# %%
data={'Democratic':48,'Republican':46,'Libertarian':3}
fig=plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    legend={'loc':'upper left','bbox_to_anchor':(1.1,1)}
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# **Title, Legend, Colors, Background Color, Block Color, Direction and Style
# **

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    colors=["#232066", "#983D3D", "#DCB732"],
    title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=[f"{k} ({v}%)" for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data), 'framealpha': 0},
    starting_location='NW',
    block_arranging_style='snake'
)
fig.set_facecolor('#EEEEEE')
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# # Plot with Icons - Pictogram Chart

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    colors=["#232066", "#983D3D", "#DCB732"],
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    icons='child',
    font_size=12,
    icon_legend=True
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# # Word Cloud

# %%
# !pip install wordcloud

# %%
# Libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Create a list of word
text=("oh oh oh oh  oh verse wrote book stand title book would life superman thats make feel count privilege love ideal honored know feel see everyday things things say rock baby truth rock love rock rock everything need rock baby rock wanna kiss ya feel ya please ya right wanna touch ya love ya baby night")
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # TEST

# %% [markdown]
# # 1. Plot a simple line graph where the x-values range from 0 to 10 and the y-values are the squares of the x-values. Label the x-axis as 'x' and the y-axis as 'y = x^2'. Give the plot a title of 'Simple Line Plot'

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,11)
y=x**2
plt.plot(x,y,"o")
plt.title("Simple Line Plot")
plt.xlabel("x")
plt.ylabel(' y = x^2')
plt.show()

# %% [markdown]
# # 2. Recreate the line graph from the first question, but this time make the line dashed and red in color.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,11)
y=x**2
plt.plot(x,y,"--r")
plt.title("Simple Line Plot")
plt.xlabel("x")
plt.ylabel(' y = x^2')
plt.show()

# %% [markdown]
# #3. Modify the plot from the previous question by adding a legend with the label "y = x^2".

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,11)
y=x**2
plt.plot(x,y,"--r")
plt.title("Simple Line Plot")
plt.xlabel("x")
plt.ylabel(' y = x^2')
mylabels=["y = x^2"]
plt.legend(mylabels)
plt.show()

# %% [markdown]
# # 4. Plot two functions on the same graph: y = x^2 and y = x^3. Use different colors for each line and include a legend

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,11)
y=x**2
z=x**3
plt.plot(y)
plt.plot(z)
plt.title("Simple Line Plot")
plt.xlabel("x")
plt.ylabel(' y = x^2')
mylabels=["x^2","x^3"]
plt.legend(mylabels)
plt.show()

# %% [markdown]
# # 5. Create a bar graph with categories 'A', 'B', 'C', 'D' and corresponding values [3, 7, 2, 5]. Label the x-axis as 'Categories' and the y-axis as 'Values'.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,7,2,5])
plt.bar(x,y)
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # 6. Recreate the bar graph from the previous question, but this time make it horizontal.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,7,2,5])
plt.barh(x,y)
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # 7. Create a scatter plot with 50 random x-values and 50 random y-values between 0 and 1. Label the x-axis as 'x' and the y-axis as 'y'

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# # 8. Recreate the scatter plot from the previous question, but use red star markers ('*') instead of the default markers.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y , marker='*',color='red')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# # 9. Generate 1000 random numbers from a normal distribution and plot a histogram with 30 bins. Set the color of the bars to green and add a title.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(1000)
plt.hist(x,bins=30,color='green')
plt.title("Histogram")
plt.show()

# %% [markdown]
# # 10. Create a pie chart with values [15, 30, 45, 10] and corresponding labels ['Category A', 'Category B', 'Category C', 'Category D']. Display the percentage of each category in the chart.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([15, 30, 45, 10])
mylabels=['Category A', 'Category B', 'Category C', 'Category D']
plt.pie(x,labels=mylabels)
plt.show()

# %% [markdown]
# # 11. Add a grid to the simple line plot created in the first question

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.grid()
plt.show()

# %% [markdown]
# # 12. Create a plot with the same data as the first question, but this time make the figure size 10x6 inches

# %%
from matplotlib import figure
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.figure(figsize=(10,6))
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# # 13. Create a subplot with 2 rows and 1 column. In the first subplot, plot y=x^2 and in the second subplot, plot y = x^3

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array([0,1,2,3])
y=x**2
plt.subplot(1,2,1)
plt.plot(y)

z=x**3
plt.subplot(1,2,2)
plt.plot(x)
plt.show()

# %% [markdown]
# # 14. For the plot y=x^2, set the x-axis limits to [0, 20] and the y-axis limits to [0, 400]. Plot the graph with these custom limits

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,22)
y=x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 15. Plot two lines on the same graph: the first line goes through the points (0, 1), (1, 3), (2, 5) and the second line goes through the points (0, 2), (1, 4), (2, 6). Use different colors for each line and add a legend

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array([0,1,2])
y= np.array([1,3,5])
plt.plot(x,y,label="line1")
e= np.array([0,1,2])
d= np.array([2,4,6])
plt.plot(e,d,label="line2")
plt.legend()
plt.show()

# %% [markdown]
# #16.Create two subplots in a single row. The first subplot should display a line plot for the points (1, 1), (2, 2), (3, 3). The second subplot should display a line plot for the points (1, 3), (2, 2), (3, 1). Title each subplot.

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.array([1,2,3])
y= np.array([1,2,3])
plt.subplot(1,2,1)
plt.title("graph 1")
plt.plot(x,y)
e= np.array([1,2,3])
d= np.array([3,2,1])
plt.subplot(1,2,2)
plt.title("graph 2")
plt.scatter(e,d)
plt.show()

# %% [markdown]
# #17.Plot a histogram using the dataset [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]. Use 4 bins. Add labels and a title

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1, 2, 2, 3, 3, 3, 4, 4, 4, 4])
plt.hist(x,bins=4)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# #18. Create a stacked bar graph for the categories 'A', 'B', 'C','D' with two datasets: [10,20,10,30] and [20,25,15,25]. Stack the second dataset on top of the first

# %%
import matplotlib.pyplot as plt
a = ['A', 'B', 'C','D']
data1 = [10,20,10,30]
data2 = [20,25,15,25]
plt.bar(a, data1, label='Dataset 1',color="red")
plt.bar(a, data2, bottom=data1, label='Dataset 2',color="blue")
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Graph')
plt.legend()
plt.show()

# %% [markdown]
# #19.create pie chart with this info
#  continents = ['Asia', 'Europe', 'North America', 'South America','Australia', 'Africa', 'Antarctica']
#
# area [25, 20, 15, 10,15,10,5]
#
# explode (0.1, 0, 0.1, 0,0.1,0.1,0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([25, 20, 15, 10,15,10,5])
mylabels=['Asia', 'Europe', 'North America', 'South America','Australia', 'Africa', 'Antarctica']
explode=(0.1, 0, 0.1, 0,0.1,0.1,0.1)
plt.pie(x,labels=mylabels,explode=explode)
plt.show()

# %% [markdown]
# #20.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5]
y=[3,3,3,3,3]
plt.plot(x,y,label='line 1',color='blue')
plt.axvline(x=3,linestyle='--',label='line 2',color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Plot')
plt.legend()
plt.show()

# %% [markdown]
# # 21

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([89,43,36,36,95,10,66,34,38,20])
y=np.array([21,46,3,35,67,95,53,72,58,10])
plt.plot(x,y,'*',color="red")
u=np.array([26,29,48,64,6,5,36,66,72,40])
v=np.array([26,34,90,33,38,20,56,2,47,15])
plt.plot(u,v,'o',color="darkblue")
plt.show()
